# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\OWNER\Downloads\archive (37).zip")

# %%
df
# Out:
#       order_id customer_id product_id     category   price  discount  \
# 0      O100000      C17270    P234890         Home  164.08      0.15
# 1      O100001      C17603    P228204      Grocery   24.73      0.00
# 2      O100002      C10860    P213892  Electronics  175.58      0.05
# 3      O100003      C15390    P208689  Electronics   63.67      0.00
# 4      O100004      C15226    P228063         Home   16.33      0.15
# ...        ...         ...        ...          ...     ...       ...
# 34495  O134495      C13553    P231412      Fashion   10.44      0.20
# 34496  O134496      C11349    P218266       Beauty    4.79      0.10
# 34497  O134497      C12986    P204345  Electronics  323.64      0.00
# 34498  O134498      C17196    P217644         Home   23.09      0.05
# 34499  O134499      C13330    P207047         Home   76.84      0.00
#
#        quantity payment_method  order_date  delivery_time_days region  \
# ...

# %%
df.head()
# Out:
#   order_id customer_id product_id     category   price  discount  quantity  \
# 0  O100000      C17270    P234890         Home  164.08      0.15         1
# 1  O100001      C17603    P228204      Grocery   24.73      0.00         1
# 2  O100002      C10860    P213892  Electronics  175.58      0.05         1
# 3  O100003      C15390    P208689  Electronics   63.67      0.00         1
# 4  O100004      C15226    P228063         Home   16.33      0.15         1
#
#   payment_method  order_date  delivery_time_days region returned  \
# 0    Credit Card  2023-12-23                   4   West       No
# 1    Credit Card  2025-04-03                   6  South       No
# 2    Credit Card  2024-10-08                   4  North       No
# 3            UPI  2024-09-14                   6  South       No
# 4            COD  2024-12-21                   6   East       No
#
#    total_amount  shipping_cost  profit_margin  customer_age customer_gender
# ...

# %%
df.tail()
# Out:
#       order_id customer_id product_id     category   price  discount  \
# 34495  O134495      C13553    P231412      Fashion   10.44      0.20
# 34496  O134496      C11349    P218266       Beauty    4.79      0.10
# 34497  O134497      C12986    P204345  Electronics  323.64      0.00
# 34498  O134498      C17196    P217644         Home   23.09      0.05
# 34499  O134499      C13330    P207047         Home   76.84      0.00
#
#        quantity payment_method  order_date  delivery_time_days region  \
# 34495         1     Debit Card  2025-08-13                   3  North
# 34496         5     Debit Card  2023-12-04                   6  South
# 34497         5    Credit Card  2025-02-01                   6   East
# 34498         1    Credit Card  2024-03-27                   6   East
# 34499         1     Debit Card  2025-09-11                   6   East
#
#       returned  total_amount  shipping_cost  profit_margin  customer_age  \
# ...

# %%
df.shape
# Out:
# (34500, 17)

# %%
df.describe()
# Out:
#               price      discount      quantity  delivery_time_days  \
# count  34500.000000  34500.000000  34500.000000        34500.000000
# mean     119.391632      0.049291      1.490725            4.814203
# std      195.620477      0.069894      0.932270            1.242141
# min        1.010000      0.000000      1.000000            3.000000
# 25%       16.690000      0.000000      1.000000            4.000000
# 50%       45.660000      0.000000      1.000000            5.000000
# 75%      130.950000      0.100000      2.000000            6.000000
# max     2930.470000      0.300000      5.000000           13.000000
#
#        total_amount  shipping_cost  profit_margin  customer_age
# count  34500.000000   34500.000000   34500.000000  34500.000000
# mean     170.008494       6.152120      28.116505     43.474377
# std      357.503014       2.389539      53.352947     14.980682
# min        0.820000       0.000000      -6.200000     18.000000
# ...

# %%
df.sample()
# Out:
#       order_id customer_id product_id category  price  discount  quantity  \
# 23641  O123641      C14625    P219493  Fashion  80.88      0.05         1
#
#       payment_method  order_date  delivery_time_days region returned  \
# 23641    Credit Card  2025-04-23                   5   West       No
#
#        total_amount  shipping_cost  profit_margin  customer_age  \
# 23641         76.84           6.87          20.02            49
#
#       customer_gender
# 23641            Male

# %%
df.columns
# Out:
# Index(['order_id', 'customer_id', 'product_id', 'category', 'price',
#        'discount', 'quantity', 'payment_method', 'order_date',
#        'delivery_time_days', 'region', 'returned', 'total_amount',
#        'shipping_cost', 'profit_margin', 'customer_age', 'customer_gender'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# order_id              0
# customer_id           0
# product_id            0
# category              0
# price                 0
# discount              0
# quantity              0
# payment_method        0
# order_date            0
# delivery_time_days    0
# region                0
# returned              0
# total_amount          0
# shipping_cost         0
# profit_margin         0
# customer_age          0
# customer_gender       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# OBSERVATION:--After data inspection was carriedout on on the dataset.
# Total rows: 34,500.
# Columns: 17.
# Time range: Sept 2023 – Sept 2025.
# No missing values detected — dataset is clean and complete.
# The data has no Null or duplicate and it's clean for analysis.

# %%
# Convert order_date to datetime 
df['order_date'] = pd.to_datetime(df['order_date'])

# %%
# Group sales by month and year
df['YearMonth'] = df['order_date'].dt.to_period('M')
sales_over_time = df.groupby('YearMonth')['total_amount'].sum().reset_index()

# %%
# Convert period to string for labeling
sales_over_time['YearMonth'] = sales_over_time['YearMonth'].astype(str)

# %%
plt.figure(figsize=(10, 5))
plt.plot(sales_over_time['YearMonth'], sales_over_time['total_amount'], marker='o', color='blue', linewidth=2)
plt.title("Sales Trend (by Month & Year)"),
plt.xlabel("Month & Year")
plt.ylabel("Total Sales ($)")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Sales show fluctuating growth across 2023–2025 with seasonal spikes around December (holiday period).
#
# Dip observed in september 2013, 2024,and also 2025 possibly due to off-peak demand.
#
# Insight: Sales seasonality exists — likely driven by festive or promotional events.
#
# Recommendation:
#
# Plan targeted marketing campaigns around high-performing months.
#
# Offer discounts or free shipping during low-demand months to balance revenue.

# %%
Sales_by_region= df.groupby("region")["total_amount"].sum().reset_index().sort_values(by="total_amount",ascending =False)

# %%
Sales_by_region
# Out:
#     region  total_amount
# 3    South    1298096.07
# 2    North    1264008.35
# 4     West    1186350.50
# 1     East    1176334.75
# 0  Central     940503.38

# %%
plt.figure(figsize=(8,5))
sns.scatterplot( data=Sales_by_region, x="region", y="total_amount",hue="region",palette="Set2")
plt.title("Price Distribution By Region")
plt.xlabel("region")
plt.ylabel("Amount")
plt.xticks(rotation=15)
plt.show()

# %% [markdown]
# South and North regions lead in total sales.
#
# West and East shows moderate activity, while Central is less engaged.
#
# Insight: Regional demand varies significantly.
#
# Recommendation:
#
# Focus ads and delivery optimization in South/North.
#
# Conduct surveys in low-performing regions to identify barriers (e.g., shipping cost, awareness).

# %%
#category
Top_5_product_category_by_sales = df.groupby("category")["total_amount"].sum().reset_index().sort_values(by="total_amount",ascending =False)[:5]

# %%
Top_5_product_category_by_sales
# Out:
#       category  total_amount
# 1  Electronics    3319206.50
# 4         Home    1077681.52
# 5       Sports     629825.54
# 2      Fashion     471545.80
# 0       Beauty     153019.38

# %%
plt.figure(figsize=(8,5))
sns.barplot( data=Top_5_product_category_by_sales, x="category", y="total_amount",hue="category",palette="Set2")
plt.title("Top 5 Product Category by Revenue")
plt.xlabel("product category")
plt.ylabel("Amount")
plt.xticks(rotation=15)
plt.show()

# %% [markdown]
# Top categories: Electronics,Home and sports are the top 3 product categories that contribute the most to total revenue.
#
# Least performing: Fashion and Beauty.
#
# Insight: Few categories dominate revenue.
#
# Recommendation:
#
# Strengthen inventory and promotion for Fashion,Beauty and other categories that are least performing.
#
# Run promotional offers and campaigns for underperforming categories like Beauty.

# %%
#payment_method

Payment_Method_by_Revenue = df.groupby("payment_method")["total_amount"].sum().reset_index().sort_values(by="total_amount",ascending =False)

# %%
Payment_Method_by_Revenue
# Out:
#   payment_method  total_amount
# 1    Credit Card    2056787.40
# 2     Debit Card    1460210.97
# 0            COD     715571.90
# 4            UPI     713642.96
# 3         PayPal     576523.32
# 5         Wallet     342556.50

# %%
sizes = [2056787.40,1460210.97,715571.90,713642.96,576523.32,342556.50]
labels = ["Credit Card","Debit Card","COD","UPI","PayPal","Wallet"]
plt.pie(sizes,labels=labels,colors=sns.color_palette("Set2"),autopct='%1.1f%%',)
plt.xticks(rotation=40)
plt.title("Payment Method by Revenue")
plt.show()

# %% [markdown]
# Credit Card is the most used (35.1%), followed by Debit Card and Cash on Delivery (COD).
#
# PayPal and Wallet are less common.
#
# Insight: Customers prefer instant payment methods.
#
# Recommendation:
#
# Encourage digital payment incentives (e.g., cashback for UPI/wallets).

# %%
#demographics

customer_by_age_group= df.groupby("customer_age")["customer_id"].count().reset_index().sort_values(by="customer_id",ascending =False)

# %%
plt.savefig("Sales Trend (by Month & Year).png")
plt.savefig("Price Distribution by region.png")
plt.savefig("Top 5 Product Category by Revenue.png")
plt.savefig("Payment Method by Revenue.png")

# %% [markdown]
#  Customer Demographics

# %%
##CUSTOMER_AGE
df["customer_age"]
# Out:
# 0        60
# 1        37
# 2        34
# 3        21
# 4        39
#          ..
# 34495    23
# 34496    61
# 34497    41
# 34498    27
# 34499    19
# Name: customer_age, Length: 34500, dtype: int64

# %%
Customer_Age_Range = df.groupby("customer_age")["customer_id"].count().reset_index()

# %%
Customer_Age_Range
# Out:
#     customer_age  customer_id
# 0             18          647
# 1             19          675
# 2             20          672
# 3             21          644
# 4             22          601
# 5             23          653
# 6             24          663
# 7             25          743
# 8             26          658
# 9             27          650
# 10            28          662
# 11            29          680
# 12            30          669
# 13            31          666
# 14            32          649
# 15            33          696
# 16            34          682
# 17            35          666
# 18            36          658
# 19            37          659
# 20            38          686
# 21            39          625
# 22            40          668
# 23            41          689
# 24            42          642
# 25            43          709
# 26            44          657
# 27            45          685
# 28            46          673
# 29            47          672
# ...

# %%
average_mean =round(df["customer_age"].mean(),1)

# %%
average_mean
# Out:
# 43.5

# %% [markdown]
# Insight: Age range: 18–69, average ~44 years
# Majority of the company's customers are Middle-aged
#
# Recommendation:
#
# Use personalized marketing (e.g., product recommendations by age group).
#
# Consider introducing youth-oriented promotions to grow younger segments.

# %%
# customer_gender
df['customer_gender_group'] = df['customer_gender'].apply(lambda x: "Male" if "Male" in x 
    else ("Female" if "Female" in x else "Unspecified"))

# %%
customer_gender = df.groupby("customer_gender_group")["customer_id"].count().reset_index().sort_values(by="customer_id",ascending =False)

# %%
customer_gender
# Out:
#   customer_gender_group  customer_id
# 0                Female        16818
# 1                  Male        16310
# 2           Unspecified         1372

# %%
sizes = [16818,16310,1372]
labels = ["Female","Male","Unspecified"]
plt.pie(sizes,labels=labels,colors=sns.color_palette("Set2"),autopct='%1.1f%%',)
plt.xticks(rotation=40)
plt.title("Customers by Gender")
plt.show()

# %% [markdown]
# Gender: Female (49%), Male (47%),Unspecified (4%)
# There is balance in gender.
